# %%
#import all required libraries etc

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
#load the data and check it out

data = pd.read_csv('mass_balance_series.csv',index_col='glacier name')
data.head()
# Out:
#                 lat    lon      1952      1953      1954      1955      1956  \
# glacier name
# Leviy Aktru   50.08  87.72 -0.039076 -0.387148  0.407494 -0.742612  0.167912
# Maliy aktru   50.04  87.74  0.005217 -0.219182  0.417785 -0.501317  0.223608
# Praviy        50.08  87.73  0.344194 -0.127647  0.801366 -0.305893  0.668040
# Shumskiy      45.08  80.23 -0.044246 -1.018890  0.050857 -0.979030 -0.463213
# Muravlev      45.10  80.23 -0.873740 -1.146919 -0.570185 -1.546340 -1.127734
#
#                   1957      1958      1959  ...      2005      2006      2007  \
# glacier name                                ...
# Leviy Aktru  -0.152999  0.394102 -0.202603  ... -0.200645 -0.230936 -0.283459
# Maliy aktru  -0.093815  0.362094 -0.143881  ... -0.151372 -0.098519 -0.195602
# Praviy        0.169110  0.779003  0.068945  ...  0.144794  0.067226 -0.012977
# Shumskiy     -0.960928  0.149613 -0.669871  ... -0.978870 -0.967204 -0.607208
# Muravlev     -1.141556 -0.482739 -1.018809  ... -1.575951 -1.405327 -1.199761
#
#                   2008      2009      2010      2011      2012      2013  \
# glacier name
# Leviy Aktru  -0.459948  0.294576  0.161884 -0.278179 -0.816668  0.200415
# Maliy aktru  -0.310556  0.295370  0.157705 -0.193454 -0.613413  0.185756
# Praviy       -0.147379  0.614224  0.605467  0.087284 -0.678764  0.410575
# Shumskiy     -1.943291 -0.549278 -0.391488 -0.742038 -1.436223 -0.642389
# Muravlev     -2.303764 -0.963703 -1.101539 -1.352273 -1.781058 -1.132839
#
#                   2014
# glacier name
# Leviy Aktru   0.111513
# Maliy aktru   0.123379
# Praviy        0.648320
# Shumskiy     -1.309745
# Muravlev     -1.761882
#
# [5 rows x 65 columns]

# %%
#take out lat/lon for plotting

lat = data['lat']
lon = data['lon']

data = data.drop(['lat','lon'],axis=1)
data.head() #check to see if lat/lon are removed from data

minYear = np.int(list(data.columns)[0]) #first year of data
maxYear = np.int(list(data.columns)[-1]) #final year of data

# %%
#plot mean mass balance for each glacier

plt.scatter(lon, lat,
            c = data.mean(axis=1),
            cmap = 'RdBu',
            edgecolor='k',
            s = 100)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Average Mass Balance of Himalayan Glaciers')
plt.colorbar()
plt.show()

# %%
#plot all time series to see what the data is that we're working with here

plt.plot(range(minYear,maxYear+1),data.T)
plt.show()

#note that data is on same scale, and since we are interested in the raw values (and not the relative shapes), we won't normalize.
